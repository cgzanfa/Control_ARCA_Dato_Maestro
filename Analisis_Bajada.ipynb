# %%
import pandas as pd
import win32com.client as win32
import os
import xlrd
import numpy as np
import xlsxwriter as xw
from xlsxwriter.workbook import Workbook
import requests
import urllib
from urllib import request
from zipfile import ZipFile
from os import listdir
from datetime import date
import time

# Instructivo:

#1) Crear una carpeta en el escritorio, con el nombre RG66

#2) Dentro de la carpeta tiene que estar el archivo de Excel "Documentos", en el cual se detallan los documentos ZP de la
#   transaccion FBL3N

#3) Abrir una cesion en SAP



#Detalla la direccion, en la cual se encuentra, el fichero desde el que estamos trabajando
fichero_actual = os.getcwd()




SapGuiAuto = win32.GetObject("SAPGUI")
application = SapGuiAuto.GetScriptingEngine
connection = application.Children(0)
session = connection.Children(0)




# IMPORTANTE: el script original de SAP contiene la palabra "true", pero hay que modificarla por "True" para que funcione 
#en Python
session.findById("wnd[0]").maximize
session.findById("wnd[0]/tbar[0]/okcd").text = "/n"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/tbar[0]/okcd").text = "zse16"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/ctxtP_TABLE").text = "but000"
session.findById("wnd[0]/usr/ctxtP_TABLE").caretPosition = 6
session.findById("wnd[0]/tbar[1]/btn[8]").press()
session.findById("wnd[0]/usr/ctxtI1-LOW").text = "1000000"
session.findById("wnd[0]/usr/ctxtI1-HIGH").text = "1999999"
session.findById("wnd[0]/usr/txtMAX_SEL").text = "999999"
session.findById("wnd[0]/usr/txtMAX_SEL").setFocus()
session.findById("wnd[0]/usr/txtMAX_SEL").caretPosition = 11
session.findById("wnd[0]/mbar/menu[3]/menu[0]/menu[1]").select()
session.findById("wnd[1]/tbar[0]/btn[14]").press()
session.findById("wnd[1]/usr/chk[1,4]").selected = True
session.findById("wnd[1]/usr/chk[1,6]").selected = True
session.findById("wnd[1]/usr/chk[1,6]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[6]").press()
session.findById("wnd[0]/tbar[1]/btn[8]").press()
session.findById("wnd[0]/usr/cntlGRID1/shellcont/shell").setCurrentCell (-1,"BPKIND")
session.findById("wnd[0]/usr/cntlGRID1/shellcont/shell").selectColumn ("BPKIND")
session.findById("wnd[0]/tbar[1]/btn[29]").press()
session.findById("wnd[1]/usr/ssub%_SUBSCREEN_FREESEL:SAPLSSEL:1105/ctxt%%DYN001-LOW").text = "gob"
session.findById("wnd[1]/usr/ssub%_SUBSCREEN_FREESEL:SAPLSSEL:1105/ctxt%%DYN001-LOW").caretPosition = 3
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[0]/tbar[1]/btn[45]").press()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").select()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[1]/usr/ctxtDY_PATH").text = fichero_actual
session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = "but000.txt"
session.findById("wnd[1]/usr/ctxtDY_FILENAME").caretPosition = 6
session.findById("wnd[1]/tbar[0]/btn[11]").press()




#Abre el archivo "but000" y selecciona las columnas a utilizar, asimismo les da el formato necesario para trabajarlas.
#El archivo "but000" contiene a todos los proveedores GOB (Gobierno)
but000 = pd.read_csv("but000.txt", sep="\t", encoding='latin1',
                        dtype={'Socio comercial': 'Int64'},
                        usecols=["Socio comercial"], skiprows=[0])




# IMPORTANTE: el script original de SAP contiene la palabra "true", pero hay que modificarla por "True" para que funcione 
#en Python
session.findById("wnd[0]").maximize
session.findById("wnd[0]/tbar[0]/okcd").text = "/n"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/tbar[0]/okcd").text = "zse16"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/ctxtP_TABLE").text = "lfb1"
session.findById("wnd[0]/usr/ctxtP_TABLE").caretPosition = 4
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/ctxtI1-LOW").text = "1000000"
session.findById("wnd[0]/usr/ctxtI1-HIGH").text = "1999999"
session.findById("wnd[0]/usr/ctxtI2-LOW").text = "a001"
session.findById("wnd[0]/usr/txtMAX_SEL").text = "999999"
session.findById("wnd[0]/usr/txtMAX_SEL").setFocus()
session.findById("wnd[0]/usr/txtMAX_SEL").caretPosition = 11
session.findById("wnd[0]/usr/btn%_I1_%_APP_%-VALU_PUSH").press()
session.findById("wnd[1]/usr/tabsTAB_STRIP/tabpNOSV").select()


#Eliminamos los indices, asi al ejecutar "to_clipboard()" no forman parte del numero de documento
#Informamos la columna que debe prevalecer
but000 = but000.set_index('Socio comercial')


#Copia los documentos del dataframe al portapapeles, ya sin el indice
but000.to_clipboard()



session.findById("wnd[1]/tbar[0]/btn[24]").press()
session.findById("wnd[1]/tbar[0]/btn[8]").press()
session.findById("wnd[0]/mbar/menu[3]/menu[0]/menu[1]").select()
session.findById("wnd[1]/tbar[0]/btn[14]").press()
session.findById("wnd[1]/usr/chk[1,4]").selected = True
session.findById("wnd[1]/usr/chk[1,4]").setFocus()
session.findById("wnd[1]/usr").verticalScrollbar.position = 85
session.findById("wnd[1]/usr/chk[1,17]").selected = True
session.findById("wnd[1]/usr/chk[1,17]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[6]").press()
session.findById("wnd[0]/tbar[1]/btn[8]").press()
session.findById("wnd[0]/tbar[1]/btn[45]").press()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").select()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[1]/usr/ctxtDY_PATH").text = fichero_actual
session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = "lfb1.txt"
session.findById("wnd[1]/tbar[0]/btn[11]").press()



#Abre el archivo "lfb1" y selecciona las columnas a utilizar, asimismo les da el formato necesario para trabajarlas.
#El archivo "lfb1" contiene a todos los proveedores de la sociedad A001; excluidos los GOB (Gobierno)
lfb1 = pd.read_csv("lfb1.txt", sep="\t", encoding='latin1',
                   usecols=["Proveedor", "Bloqueos Pago"], skiprows=[0])


#Seleccionamos la columna que contiene los proveedores. Posteriormente servira para indicarle a lfa1 con cuales vamos 
#a trabajar. De esta forma excluimos a los que no correspondan a la sociedad A001. 
lfb1_solo_prov = lfb1[['Proveedor']]



session.findById("wnd[0]").maximize
session.findById("wnd[0]/tbar[0]/okcd").text = "/n"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/tbar[0]/okcd").text = "zse16"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/ctxtP_TABLE").text = "lfa1"
session.findById("wnd[0]/usr/ctxtP_TABLE").caretPosition = 4
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/btn%_I1_%_APP_%-VALU_PUSH").press()



#Eliminamos los indices, asi al ejecutar "to_clipboard()" no forman parte del numero de documento
#Informamos la columna que debe prevalecer
lfb1_solo_prov = lfb1_solo_prov.set_index('Proveedor')


#Copia los documentos del dataframe al portapapeles, ya sin el indice
lfb1_solo_prov.to_clipboard()



session.findById("wnd[1]/tbar[0]/btn[24]").press()
session.findById("wnd[1]/tbar[0]/btn[8]").press()
session.findById("wnd[0]/usr/txtMAX_SEL").text = "999999"
session.findById("wnd[0]/usr/txtMAX_SEL").setFocus()
session.findById("wnd[0]/usr/txtMAX_SEL").caretPosition = 11
session.findById("wnd[0]/mbar/menu[3]/menu[0]/menu[1]").select()
session.findById("wnd[1]/tbar[0]/btn[14]").press()
session.findById("wnd[1]/usr/chk[1,4]").selected = True
session.findById("wnd[1]/usr/chk[1,6]").selected = True
session.findById("wnd[1]/usr/chk[1,6]").setFocus()
session.findById("wnd[1]/usr").verticalScrollbar.position = 1
session.findById("wnd[1]/usr").verticalScrollbar.position = 2
session.findById("wnd[1]/usr").verticalScrollbar.position = 3
session.findById("wnd[1]/usr").verticalScrollbar.position = 4
session.findById("wnd[1]/usr").verticalScrollbar.position = 5
session.findById("wnd[1]/usr").verticalScrollbar.position = 6
session.findById("wnd[1]/usr").verticalScrollbar.position = 7
session.findById("wnd[1]/usr").verticalScrollbar.position = 8
session.findById("wnd[1]/usr").verticalScrollbar.position = 9
session.findById("wnd[1]/usr").verticalScrollbar.position = 10
session.findById("wnd[1]/usr").verticalScrollbar.position = 11
session.findById("wnd[1]/usr").verticalScrollbar.position = 12
session.findById("wnd[1]/usr").verticalScrollbar.position = 13
session.findById("wnd[1]/usr").verticalScrollbar.position = 14
session.findById("wnd[1]/usr").verticalScrollbar.position = 15
session.findById("wnd[1]/usr").verticalScrollbar.position = 16
session.findById("wnd[1]/usr").verticalScrollbar.position = 17
session.findById("wnd[1]/usr").verticalScrollbar.position = 18
session.findById("wnd[1]/usr").verticalScrollbar.position = 19
session.findById("wnd[1]/usr").verticalScrollbar.position = 20
session.findById("wnd[1]/usr").verticalScrollbar.position = 21
session.findById("wnd[1]/usr").verticalScrollbar.position = 22
session.findById("wnd[1]/usr").verticalScrollbar.position = 23
session.findById("wnd[1]/usr").verticalScrollbar.position = 24
session.findById("wnd[1]/usr/chk[1,19]").selected = True
session.findById("wnd[1]/usr/chk[1,19]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[6]").press()
session.findById("wnd[0]/tbar[1]/btn[8]").press()
session.findById("wnd[0]/tbar[1]/btn[45]").press()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").select()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[1]/usr/ctxtDY_PATH").text = fichero_actual
session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = "lfa1.txt"
session.findById("wnd[1]/tbar[0]/btn[11]").press()



lfa1 = pd.read_csv("lfa1.txt", sep="\t", encoding='latin1',
                   usecols=["Proveedor", "Nombre 1", "Nº ident.fis.1"], skiprows=[0,2])



session.findById("wnd[0]").maximize
session.findById("wnd[0]/tbar[0]/okcd").text = "/n"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/tbar[0]/okcd").text = "zse16"
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/ctxtP_TABLE").text = "lfbw"
session.findById("wnd[0]/usr/ctxtP_TABLE").caretPosition = 4
session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/btn%_I1_%_APP_%-VALU_PUSH").press()


#Copia los documentos del dataframe al portapapeles, ya sin el indice
lfb1_solo_prov.to_clipboard()


session.findById("wnd[0]").sendVKey (0)
session.findById("wnd[0]/usr/btn%_I1_%_APP_%-VALU_PUSH").press()
session.findById("wnd[1]/tbar[0]/btn[24]").press()
session.findById("wnd[1]/tbar[0]/btn[8]").press()
session.findById("wnd[0]/usr/ctxtI2-LOW").text = "a001"
session.findById("wnd[0]/usr/txtMAX_SEL").text = "999999"
session.findById("wnd[0]/usr/txtMAX_SEL").setFocus()
session.findById("wnd[0]/usr/txtMAX_SEL").caretPosition = 11
session.findById("wnd[0]/tbar[1]/btn[8]").press()
session.findById("wnd[0]/usr/cntlGRID1/shellcont/shell").setCurrentCell (-1,"WT_SUBJCT")
session.findById("wnd[0]/usr/cntlGRID1/shellcont/shell").selectColumn ("WT_SUBJCT")
session.findById("wnd[0]/tbar[1]/btn[29]").press()
session.findById("wnd[1]/usr/ssub%_SUBSCREEN_FREESEL:SAPLSSEL:1105/ctxt%%DYN001-LOW").text = "x"
session.findById("wnd[1]/usr/ssub%_SUBSCREEN_FREESEL:SAPLSSEL:1105/ctxt%%DYN001-LOW").caretPosition = 1
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[0]/tbar[1]/btn[45]").press()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").select()
session.findById("wnd[1]/usr/subSUBSCREEN_STEPLOOP:SAPLSPO5:0150/sub:SAPLSPO5:0150/radSPOPLI-SELFLAG[1,0]").setFocus()
session.findById("wnd[1]/tbar[0]/btn[0]").press()
session.findById("wnd[1]/usr/ctxtDY_PATH").text = fichero_actual
session.findById("wnd[1]/usr/ctxtDY_FILENAME").text = "lfbw.txt"
session.findById("wnd[1]/tbar[0]/btn[11]").press()



lfbw = pd.read_csv("lfbw.txt", sep="\t", encoding='latin1',
                   skiprows=[0,2])







#Obtenemos el archivo zip de la pagina web con la que vamos a trabajar
#Se guarda en la misma carpeta donde se encuentra el script a ejecutar
dls = "https://www.afip.gob.ar/genericos/cInscripcion/archivos/apellidoNombreDenominacion.zip"
urllib.request.urlretrieve(dls, "test.zip")

with ZipFile('test.zip', 'r') as f:
    f.extractall('archivos')
    
    
carpeta = 'C:/Users/u531723/Desktop/CAP/PANDAS/PYTHON - ZFI0216/archivos/utlfile/padr/'
listafiles = os.listdir(carpeta)

archivo = listafiles[0]



#renombrar el archivo como AFIP
data2 = pd.read_fwf(carpeta + archivo, encoding='latin1', widths = [11,30,2,2,2,1,1,2], header=None)
data2.columns = ['CUIT','DENOMINACION AFIP','IMP GANANCIAS','IMP IVA', 'MONOTRIBUTO', 'INTEGRANTE SOC', 'EMPLEADOR', 'ACTIVIDAD MONOTRIBUTO']


# Excluir los proveedores GOB (Gobierno)
excel1 = pd.DataFrame(data2)

df2 = lfa1

# Renombrar la columna CUIT
df2 = df2.rename(columns={'Nº ident.fis.1':'CUIT'})

#Las razones sociales corresponden a la AFIP
Analisis = pd.merge(excel1, df2, how = 'right')

#Genera una nueva tabla y compara las razones sociales
Analisis = Analisis.rename(columns={'Nombre 1':'DENOMINACION SAP'})

Analisis10 = Analisis[['Proveedor', 'DENOMINACION AFIP', 'DENOMINACION SAP']]



# Ordenar las columnas
Analisis1 = Analisis[['Proveedor', 'DENOMINACION AFIP', 'CUIT', 'IMP GANANCIAS','IMP IVA', 'MONOTRIBUTO', 'INTEGRANTE SOC', 'EMPLEADOR', 'ACTIVIDAD MONOTRIBUTO']]

LFBW = lfbw

#Selecciono las columnas del archivo LFBW con las que voy a trabajar
T_Ret = LFBW[['Proveedor', 'Tipo retenciones']]

#Filtra GANANCIAS para armar una columna nueva con su nombre respectivo
GA = T_Ret[T_Ret['Tipo retenciones'] == 'GA']

GD = T_Ret[T_Ret['Tipo retenciones'] == 'GD']

GE = T_Ret[T_Ret['Tipo retenciones'] == 'GE']

GF = T_Ret[T_Ret['Tipo retenciones'] == 'GF']

GI = T_Ret[T_Ret['Tipo retenciones'] == 'GI']

G1 = T_Ret[T_Ret['Tipo retenciones'] == 'G1']

G3 = T_Ret[T_Ret['Tipo retenciones'] == 'G3']

MG = T_Ret[T_Ret['Tipo retenciones'] == 'MG']

MI = T_Ret[T_Ret['Tipo retenciones'] == 'MI']

# Filtra IVA
IV = T_Ret[T_Ret['Tipo retenciones'] == 'IV']

IZ = T_Ret[T_Ret['Tipo retenciones'] == 'IZ']

# Filtra SUSS
CM = T_Ret[T_Ret['Tipo retenciones'] == 'CM']

CO = T_Ret[T_Ret['Tipo retenciones'] == 'CO']

CP = T_Ret[T_Ret['Tipo retenciones'] == 'CP']

CT = T_Ret[T_Ret['Tipo retenciones'] == 'CT']

EE = T_Ret[T_Ret['Tipo retenciones'] == 'EE']

LI = T_Ret[T_Ret['Tipo retenciones'] == 'LI']

SE = T_Ret[T_Ret['Tipo retenciones'] == 'SE']


# Selecciona las columnas que quiero utilizar para hacer el Buscarv
Analisis = Analisis1[['Proveedor', 'DENOMINACION AFIP', 'CUIT', 'IMP GANANCIAS', 'IMP IVA','MONOTRIBUTO', 'EMPLEADOR', 'ACTIVIDAD MONOTRIBUTO']]

#Buscarv
# Renombra las columnas 'Tipo retenciones' para que no se dupliquen en el data frame
Control = pd.merge(Analisis, GA, on = "Proveedor", how = 'left')

Control = Control.rename(columns={'Tipo retenciones':'GA'})

Control1 = pd.merge(Control, GD, how = 'left', on = "Proveedor")

Control1 = Control1.rename(columns={'Tipo retenciones':'GD'})

Control2 = pd.merge(Control1, GE, how= 'left', on = "Proveedor")

Control2 = Control2.rename(columns={'Tipo retenciones':'GE'})

Control3 = pd.merge(Control2, GF, how= 'left', on = "Proveedor")

Control3 = Control3.rename(columns={'Tipo retenciones':'GF'})

Control4 = pd.merge(Control3, GI, how= 'left', on = "Proveedor")

Control4 = Control4.rename(columns={'Tipo retenciones':'GI'})

Control5 = pd.merge(Control4, G1, how= 'left', on = "Proveedor")

Control5 = Control5.rename(columns={'Tipo retenciones':'G1'})

Control6 = pd.merge(Control5, G3, how= 'left', on = "Proveedor")

Control6 = Control6.rename(columns={'Tipo retenciones':'G3'})

Control7 = pd.merge(Control6, MG, how= 'left', on = "Proveedor")

Control7 = Control7.rename(columns={'Tipo retenciones':'MG'})

Control8 = pd.merge(Control7, MI, how= 'left', on = "Proveedor")

Control8 = Control8.rename(columns={'Tipo retenciones':'MI'})

Control9 = pd.merge(Control8, IV, how= 'left', on = "Proveedor")

Control9 = Control9.rename(columns={'Tipo retenciones':'IV'})

Control10 = pd.merge(Control9, IZ, how= 'left', on = "Proveedor")

Control10 = Control10.rename(columns={'Tipo retenciones':'IZ'})


Control11 = pd.merge(Control10, CM, how= 'left', on = "Proveedor")

Control11 = Control11.rename(columns={'Tipo retenciones':'CM'})

Control12 = pd.merge(Control11, CO, how= 'left', on = "Proveedor")

Control12 = Control12.rename(columns={'Tipo retenciones':'CO'})

Control13 = pd.merge(Control12, CP, how= 'left', on = "Proveedor")

Control13 = Control13.rename(columns={'Tipo retenciones':'CP'})

Control14 = pd.merge(Control13, CT, how= 'left', on = "Proveedor")

Control14 = Control14.rename(columns={'Tipo retenciones':'CT'})

Control15 = pd.merge(Control14, EE, how= 'left', on = "Proveedor")

Control15 = Control15.rename(columns={'Tipo retenciones':'EE'})

Control16 = pd.merge(Control15, LI, how= 'left', on = "Proveedor")

Control16 = Control16.rename(columns={'Tipo retenciones':'LI'})

Control17 = pd.merge(Control16, SE, how= 'left', on = "Proveedor")

Control17 = Control17.rename(columns={'Tipo retenciones':'SE'})



LFB1 = lfb1

Analisis2 = pd.merge(Control17, LFB1, how = 'left', on = "Proveedor")

EQUIVALENCIA = pd.read_excel('EQUIVALENCIAS.xlsx')


Analisis3 = pd.merge(Analisis2, EQUIVALENCIA, how = 'left', on = "IMP GANANCIAS") 

Analisis3 = Analisis3.rename(columns={'EQUIVALENCIA':'EQ GAN'})

Analisis3 = Analisis3[['Proveedor', 'DENOMINACION AFIP', 'CUIT', 'Bloqueos Pago', 'IMP GANANCIAS', 'EQ GAN', 'GA', 'GD', 'GE', 'GF', 'GI', 'G1', 'G3','MONOTRIBUTO', 'MG', 'MI', 'IMP IVA', 'IV', 'IZ', 'EMPLEADOR', 'CM', 'CO', 'CP', 'CT', 'EE', 'LI', 'SE', 'ACTIVIDAD MONOTRIBUTO']]


# Prueba logica que determina si el proveedor es MONOTRIBUTISTA
Analisis3.loc[((Analisis3['MONOTRIBUTO'] != "NI") & (Analisis3['MONOTRIBUTO'] != "NaN")) & ((Analisis3['ACTIVIDAD MONOTRIBUTO'] == 8) | (Analisis3['ACTIVIDAD MONOTRIBUTO'] == 10)), 'EQ MONO'] = "MONOTRIBUTO"
Analisis3.loc[~(((Analisis3['MONOTRIBUTO'] != "NI") & (Analisis3['MONOTRIBUTO'] != "NaN")) & ((Analisis3['ACTIVIDAD MONOTRIBUTO'] == 8) | (Analisis3['ACTIVIDAD MONOTRIBUTO'] == 10))), 'EQ MONO'] = ""
Analisis3.loc[(Analisis3['EQ MONO'] == "MONOTRIBUTO") & (Analisis3['MG'] != "NaN") & (Analisis3['MI'] != "NAN"), 'CONTROL'] = "OK"

#Totaliza la cantidad de tipos de retencion de Ganancias 
CantidadGA = Analisis3[['GA', 'GD', 'GE', 'GF', 'GI', 'G1', 'G3']]

CantidadGA = CantidadGA.count(axis = 1)

Analisis3['Ʃ GAN'] = pd.DataFrame(CantidadGA, columns=['Ʃ GAN'])


#Totaliza la cantidad de tipos de retencion de IVA 
CantidadIV = Analisis3[['IV', 'IZ']]

CantidadIV = CantidadIV.count(axis = 1)

Analisis3['Ʃ IVA'] = pd.DataFrame(CantidadIV, columns=['Ʃ IVA'])


#Totaliza la cantidad de tipos de retencion de Empleador 
CantidadCP = Analisis3[['CM', 'CO', 'CP', 'CT', 'EE', 'LI', 'SE']]

CantidadCP = CantidadCP.count(axis = 1) 

Analisis3['Ʃ EMP'] = pd.DataFrame(CantidadCP, columns=['Ʃ EMP'])


Analisis4 = Analisis3[['Proveedor', 'DENOMINACION AFIP', 'CUIT', 'Bloqueos Pago', 'IMP GANANCIAS', 'EQ GAN', 'GA', 'GD', 'GE', 'GF', 'GI', 'G1', 'G3', 'Ʃ GAN','MONOTRIBUTO', 'EQ MONO', 'MG', 'MI', 'IMP IVA', 'IV', 'IZ', 'Ʃ IVA', 'EMPLEADOR', 'CM', 'CO', 'CP', 'CT', 'EE', 'LI', 'SE', 'Ʃ EMP', 'ACTIVIDAD MONOTRIBUTO', 'CONTROL']]



##############################################
#################### RG18 ####################
##############################################


#Obtenemos el archivo de la pagina web con la que vamos a trabajar
#Se guarda en la misma carpeta donde se encuentra el script a ejecutar
#remote_url = 'https://serviciosweb.afip.gob.ar/genericos/Registros/rg18/Archivos/RG18.csv' --- (dejo de funcionar)
remote_url = 'https://servicioscf.afip.gob.ar/Publico/rg18/Archivos/RG18.csv'

local_file = 'C:/Users/u531723/Desktop/CAP/PANDAS/PYTHON - ZFI0216/RG18.csv'

#request.urlretrieve(remote_url, local_file)
response_rg18 = requests.get(remote_url)

with open('RG18.csv', 'wb') as file:
    file.write(response.content)


  
#sep=";": Indicamos que el separador es ";", ya que algunas razones sociales tienen ","
#skiprows=[0]: Omitimos la 1er fila
#parse_dates=['FECHA_HASTA']: indicamos el formato fecha para la columna 'FECHA_HASTA'
#dayfirst=True: formato dia/mes (latinoamerica)    
RG18 = pd.read_csv(local_file, sep=";", skiprows=[0], encoding='latin1', parse_dates=['FECHA_HASTA'], dayfirst=True)


#Creamos una fecha ficticia, sin vencimiento 
date_inf = pd.to_datetime('31122099', format="%d%m%Y")


#Completamos los espacios vacios (NaT) por una fecha que no caduca
RG18['FECHA_HASTA'] = RG18['FECHA_HASTA'].fillna(date_inf)


#Generamos la fecha de hoy
today = date.today()


#Le aplicamos formato
today = today.strftime("%d-%m-%Y")


#Filtramos el dataframe por las fechas mayores o iguales al dia de hoy (lo que no este vencido)
RG18 = RG18[RG18['FECHA_HASTA'] >= today]


#Damos el formato requerido a la columna 'FECHA_HASTA'. Al hacer esto se pierde la condicion datetime64[ns]
#Si queremos volver a trabajar con fechas deberemos darle formato con "pd.to_datetime"
RG18['FECHA_HASTA'] = RG18['FECHA_HASTA'].dt.strftime("%d-%m-%Y")


#Seleccionamos las columnas que vamos a utlizar y descartamos el resto
RG18 = RG18[['CUIT', 'FECHA_HASTA']]


#Hacemos una union entre la tabla RG18 y la principal
Analisis5 = pd.merge(Analisis4, RG18, how = 'left', on = "CUIT")


#Ordenamos las columnas de acuerdo a nuestra necesidad
Analisis6 = Analisis5[['Proveedor', 'DENOMINACION AFIP', 'CUIT', 'Bloqueos Pago', 'IMP GANANCIAS', 'EQ GAN', 'GA', 'GD', 'GE', 'GF', 'GI', 'G1', 'G3', 'Ʃ GAN','MONOTRIBUTO', 'EQ MONO', 'MG', 'MI', 'IMP IVA', 'FECHA_HASTA', 'IV', 'IZ', 'Ʃ IVA', 'EMPLEADOR', 'CM', 'CO', 'CP', 'CT', 'EE', 'LI', 'SE', 'Ʃ EMP', 'ACTIVIDAD MONOTRIBUTO', 'CONTROL']]



##############################################
################# XLSXWRITER #################
##############################################


#Exporta el Analisis Final a Excel con sus respectivas hojas
with pd.ExcelWriter("Analisis.xlsx") as writer:
    Analisis6.to_excel(writer, sheet_name="Analisis", startrow=1 , startcol=0) 
    Analisis1.to_excel(writer, sheet_name="AFIP") 
    Analisis10.to_excel(writer, sheet_name="DENOMINACION")
    
    
    workbook1 = writer.book
    worksheet1 = writer.sheets["Analisis"]  

    
    
    #_Ancho de las columnas
    worksheet1.set_column('A:A', 8.43)
    worksheet1.set_column('B:B', 14.14)
    worksheet1.set_column('C:C', 37.29)
    worksheet1.set_column('D:D', 12.29)
    worksheet1.set_column('E:E', 17.86)
    worksheet1.set_column('F:F', 19.71)
    worksheet1.set_column('G:G', 13.86)
    worksheet1.set_column('H:N', 7.57)
    worksheet1.set_column('O:O', 10.43)
    worksheet1.set_column('P:P', 18.71)
    worksheet1.set_column('Q:Q', 14.86)
    worksheet1.set_column('R:S', 8.14)
    worksheet1.set_column('T:T', 12)
    worksheet1.set_column('U:U', 10.14)
    worksheet1.set_column('V:W', 6.71)
    worksheet1.set_column('X:X', 9.43)
    worksheet1.set_column('Y:Y', 15.86)
    worksheet1.set_column('Z:AF', 7.86)
    worksheet1.set_column('AG:AG', 10.29)
    worksheet1.set_column('AH:AH', 29.14)
    worksheet1.set_column('AI:AI', 13.29)
    
    
    #_Color de las celdas a utilizar   
    header_format_0 = workbook1.add_format({
        'bottom': 2, #borde inferior
        'bottom_color': '#FFFFFF', #color de borde inferior
        "valign": "vcenter", #centra el texto en vertical
        "align": "center", #centra el texto en horizontal
        "bg_color": "#4BACC6", #color de la celda
        'font_color': '#FFFFFF', #color de la fuente
        'font_size': 14, #tamaño de la fuente
        'font_name': '72 Black'})
    
    
    
        #_Color de las celdas a utilizar   
    header_format_3 = workbook1.add_format({
        'border': 2, #borde
        'border_color': '#FFFFFF', #color de borde
        "valign": "vcenter", #centra el texto en vertical
        "align": "center", #centra el texto en horizontal
        "bg_color": "#000000", #color de la celda
        'font_color': '#FFFFFF', #color de la fuente
        'font_size': 14, #tamaño de la fuente
        'font_name': '72 Black'})  
    
    
    
    #Combina celdas y aplica formato
    worksheet1.merge_range('H1:N1', 'SAP', header_format_0)
    worksheet1.merge_range('R1:S1', 'SAP', header_format_0)
    worksheet1.merge_range('T1:U1', 'AFIP', header_format_3)
    worksheet1.merge_range('V1:W1', 'SAP', header_format_0)
    worksheet1.merge_range('Z1:AF1', 'SAP', header_format_0)
    
    
    
    #_Color de las celdas a utilizar SAP  
    header_format_1 = workbook1.add_format({
        "bg_color": "#8DB4E2",
        'font_color': '#FFFFFF',
        'bold': True, 
        'font_size': 12,
        'font_name': 'Calibri'})
    
    
    #_Color de las celdas a utilizar AFIP  
    header_format_2 = workbook1.add_format({
        'border': 2, #borde
        'border_color': '#FFFFFF', #color de borde
        "valign": "vcenter", #centra el texto en vertical
        "align": "center", #centra el texto en horizontal
        "bg_color": "#A6A6A6", #color de la celda
        'bold': True, #negrita
        'font_color': '#FFFFFF', #color de la fuente
        'font_size': 11, #tamaño de la fuente
        'font_name': 'Calibri'}) #nombre de la fuente    
    
    

    #_Renombra las columnas
    worksheet1.write('C1', 'AFIP', header_format_3)
    worksheet1.write('C2', 'DENOMINACION AFIP', header_format_2)
    worksheet1.write('F1', 'AFIP', header_format_3)
    worksheet1.write('F2', 'IMP GANANCIAS', header_format_2)
    worksheet1.write('H2', 'GA', header_format_1)
    worksheet1.write('I2', 'GD', header_format_1)
    worksheet1.write('J2', 'GE', header_format_1)
    worksheet1.write('K2', 'GF', header_format_1)
    worksheet1.write('L2', 'GI', header_format_1)
    worksheet1.write('M2', 'G1', header_format_1)
    worksheet1.write('N2', 'G3', header_format_1)
    worksheet1.write('P1', 'AFIP', header_format_3)
    worksheet1.write('P2', 'MONOTRIBUTO', header_format_2)
    worksheet1.write('R2', 'MG', header_format_1)
    worksheet1.write('S2', 'MI', header_format_1)
    worksheet1.write('T2', 'IMP IVA', header_format_2)
    worksheet1.write('U2', 'RG18', header_format_2)
    worksheet1.write('V2', 'IV', header_format_1)
    worksheet1.write('W2', 'IZ', header_format_1)
    worksheet1.write('Y1', 'AFIP', header_format_3)
    worksheet1.write('Y2', 'EMPLEADOR', header_format_2)
    worksheet1.write('Z2', 'CM', header_format_1)
    worksheet1.write('AA2', 'CO', header_format_1)
    worksheet1.write('AB2', 'CP', header_format_1)
    worksheet1.write('AC2', 'CT', header_format_1)
    worksheet1.write('AD2', 'EE', header_format_1)
    worksheet1.write('AE2', 'LI', header_format_1)
    worksheet1.write('AF2', 'SE', header_format_1)
    worksheet1.write('AH1', 'AFIP', header_format_3)
    worksheet1.write('AH2', 'ACTIVIDAD MONOTRIBUTO', header_format_2)
    
    
    #Ajusta la vista de la hoja a 80%
    worksheet1.set_zoom(80)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
# ...
